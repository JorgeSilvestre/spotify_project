# %% [markdown]
# # Spotify data
#
# Description: https://support.spotify.com/us/article/understanding-my-data/

# %%
import pandas as pd
import json
from pathlib import Path

# Para crear los directorios necesarios
raw_data_path = Path('./data/raw_data')
extracted_data_path = Path('./data/extracted_data')
if not raw_data_path.exists(): raw_data_path.mkdir(parents=True, exist_ok=True)
if not extracted_data_path.exists(): extracted_data_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Reproducciones

# %%
rep_data = pd.read_json('./data/raw_data/Spotify Account Data/StreamingHistory_music_0.json')
# Se eliminan registros duplicados: canciones que figuran dos veces, terminando a la vez,
# pero con duraciones de reproducción diferentes.
# Identificamos todos los registros duplicados
min_duracion = rep_data[rep_data.duplicated(subset=['endTime', 'artistName', 'trackName'], keep=False)]
display(min_duracion.head(10))
# Para cada duplicado, obtenemos el índice del de menor duración
min_duracion = min_duracion.groupby(['artistName', 'trackName', 'endTime']).idxmin()
# Descartamos los registros cuyo índice es uno de los registros en min_duracion
rep_data = rep_data[~rep_data.msPlayed.isin(min_duracion.msPlayed)]
rep_data = rep_data.reset_index(drop=True)

# Agregamos una columna con la fecha de reproducción
rep_data['playDate'] = pd.to_datetime(rep_data.endTime, format='ISO8601').values
# Agregamos una columna con el tiempo de reproducción, en minutos
rep_data['minPlayed'] = rep_data.msPlayed//60000

# %% [markdown]
# ## API

# %%
import requests

client_id = '755baf36b7e94f81ba6f0d30c9783a4e'
client_secret = '7a4998fbbe2842fabecbf4dfd319b8ae'

# %% [markdown]
# ### Get access token

# %%
# Get access token
response = requests.post(url='https://accounts.spotify.com/api/token', 
                             headers={'Content-Type':'application/x-www-form-urlencoded'},
                             data=dict(grant_type='client_credentials', 
                                       client_id=client_id, 
                                       client_secret=client_secret))
access_token = response.json().get('access_token', None)

header = {'Authorization': 'Bearer '+ access_token, }
# 'Content-Type':'application/json',

# %% [markdown]
# ### Extraction code

# %%
header = {'Authorization': 'Bearer '+ access_token, }

def search_track(artist_name: str, track_name: str) -> dict:
    """ Obtiene el ID de una canción a partir de su nombre y el de su artista

    Como el endpoint de búsqueda devuelve una lista de resultados relevantes,
    es necesario revisar los resultados para seleccionar la canción adecuada
    comparando su nombre.
    
    Argumentos:
        artist_name: Nombre del artista
        track_name: Nombre de la canción
    Devuelve:
        Diccionario con la respuesta en JSON del servidor
    """
    # Search: https://developer.spotify.com/documentation/web-api/reference/search

    params = dict(q=f'artist:"{artist_name}" track:"{track_name}"', 
                  type=['track'],
                  market='ES',
                  limit=30)
    response = requests.get(url='https://api.spotify.com/v1/search', 
                            headers=header, 
                            params=params)
    tracks = response.json()['tracks']['items']
    for track in tracks:
        if track['name'] == track_name:
            return track
    else:
        return {}


def extract_track(track_id: str) -> dict:
    # Tracks: https://developer.spotify.com/documentation/web-api/reference/tracks
    params = dict(market='ES')
    response = requests.get(url=f'https://api.spotify.com/v1/tracks/{track_id}', 
                            headers=header,
                            params=params)
    
    return response.json()

def extract_artist(artist_id: str) -> dict:
    response = requests.get(url=f'https://api.spotify.com/v1/artists/{artist_id}', 
                            headers=header)
    
    return response.json()

def extract_artist_albums(artist_id: str) -> dict:
    params = dict(include_groups='album',
                  limit=20,
                  market='ES')
    response = requests.get(url=f'https://api.spotify.com/v1/artists/{artist_id}/albums', 
                            headers=header,
                            params=params)
    
    return response.json()

def extract_album(album_id: str) -> dict:
    params = dict(market='ES')
    response = requests.get(url=f'https://api.spotify.com/v1/albums/{album_id}', 
                            headers=header, 
                            params=params)
    
    return response.json()

# %% [markdown]
# ### Extraction

# %%
rep_data = pd.read_json(data_folder / 'StreamingHistory_music_0.json')

tracks = rep_data.drop_duplicates(subset=['artistName', 'trackName']).reset_index(drop=True)
tracks.head()
# Out:
#             endTime           artistName              trackName  msPlayed
# 0  2023-04-01 07:34            El Drogas     Cordones de Mimbre         0
# 1  2023-04-01 07:37  Heroes Del Silencio               La carta    178109
# 2  2023-04-01 07:41                Keane  This Is The Last Time    208787
# 3  2023-04-01 07:46       Joaquín Sabina        Peces de Ciudad    305175
# 4  2023-04-01 07:50       Gustavo Cerati                 Puente    273758

# %%
results = []
for idx, row in tracks.iterrows():
    print(f'({idx+1:>3}/{len(tracks):>3}) {row.artistName + " - " + row.trackName:<200}', end='\r')
    result = search_track(row.artistName, row.trackName)

    if result:
        results.append(result)

# Escribir
with open('./data/extracted_data/tracks.json', 'w+', encoding='utf8') as file:
    json.dump(results, file)
# Cargar
# with open('./data/extracted_data/tracks/tracks.json', 'r', encoding='utf8') as file:
#     results = json.load(file)

# %%
tracks_data = {}
artists_data = {}
albums_data = {}

for idx, result in enumerate(results):
    track = dict(
        id=result['id'],
        name=result['name'],
        popularity=result['popularity'],
        number=result['track_number'],
        duration=result.get('duration_ms', None),
        id_album=result['album']['id'],
        id_artists=[art['id'] for art in result['artists']]
    )
    tracks_data[track['id']] = track

    for art in result['artists']:
        if art['id'] not in artists_data:
            artist = dict(
                id=art['id'],
                name=art['name'],
            )
            artists_data[art['id']] = artist

    if result['album']['id'] not in albums_data:
        album = dict(
            id=result['album']['id'],
            name=result['album']['name'],
            type=result['album']['type'],
            release_date=result['album']['release_date'],
            total_tracks=result['album']['total_tracks'],
            id_artists=[art['id'] for art in result['artists']]
        )
        albums_data[result['album']['id']] = album

df_tracks  = pd.DataFrame([x for x in tracks_data.values()])

# %%
# Completamos los artistas
for idx, artist in enumerate(artists_data.values()):
    print(f'({idx+1:>3}/{len(artists_data):>3}) {artist['name']:<200}', end='\r')
    
    art = extract_artist(artist['id'])
    artist['followers'] = art['followers']['total']
    artist['popularity'] = art['popularity']
    artist['genres'] = ','.join(art['genres'])
df_artists = pd.DataFrame([x for x in artists_data.values()])
# Out:
# (1137/1137) Scala & Kolacny Brothers                          erer

# %%
# Completamos los discos
for idx, album in enumerate(albums_data.values()):
    print(f'({idx+1:>3}/{len(albums_data):>3}) {album['name']:<200}', end='\r')
    alb = extract_album(album['id'])
    album['genres'] = ','.join(alb['genres'])
    album['label'] = alb['label']
    album['popularity'] = alb['popularity']
df_albums  = pd.DataFrame([x for x in albums_data.values()])
# Out:
# (1705/1705) On The Rocks

# %%
df_tracks.head()
# Out:
#                        id                   name  popularity  number  \
# 0  3aI5UV6m77rF4D2gYipiSL     Cordones de Mimbre          25       2
# 1  2RzZSZbfu3jir4udOhyd75               La carta          61       3
# 2  6IVlHRrjTKep5SS9kbcpTa  This Is The Last Time          67       9
# 3  5xq9JrBQQ1r1bKx3P1QhB2        Peces de Ciudad          54       6
# 4  6gwaa6ElIixNTvu6RwkMyo                 Puente          70       4
#
#    duration                id_album                id_artists
# 0    177346  5xFHWjntXM8PQ1iRUGQZHB  [5jJWnRLQeU7fe9VaDjpIWK]
# 1    187520  7DAoA2gOvycforLAKyFD8Y  [3qAPxVwIQRBuz5ImPUxpZT]
# 2    208786  0MlTOiC5ZYKFGeZ8h3D4rd  [53A0W3U0s8diEn9RhXQhVz]
# 3    305186  2V1g8Z3d12rVQl5UIACCEI  [4aeIWo5CMF1uRmqgJdwkZW]
# 4    273800  2rIdWbXPjcq8K7BCccBhhC  [1QOmebWGB6FdFtW7Bo3F0W]

# %%
df_artists.head()
# Out:
#                        id                 name  followers  popularity  \
# 0  5jJWnRLQeU7fe9VaDjpIWK            El Drogas      37139          44
# 1  3qAPxVwIQRBuz5ImPUxpZT  Heroes Del Silencio    2542226          67
# 2  53A0W3U0s8diEn9RhXQhVz                Keane    3303317          74
# 3  4aeIWo5CMF1uRmqgJdwkZW       Joaquín Sabina    2991403          67
# 4  1QOmebWGB6FdFtW7Bo3F0W       Gustavo Cerati    4238788          72
#
#                                               genres
# 0                           punk urbano,spanish punk
# 1  latin alternative,latin rock,musica aragonesa,...
# 2                     neo mellow,piano rock,pop rock
# 3                        cantautor,spanish pop,trova
# 4  argentine rock,latin alternative,latin rock,ro...

# %%
df_albums.head()
# Out:
#                        id                                     name   type  \
# 0  5xFHWjntXM8PQ1iRUGQZHB            Demasiado Tonto en la Corteza  album
# 1  7DAoA2gOvycforLAKyFD8Y  Senderos De Traición - Edición Especial  album
# 2  0MlTOiC5ZYKFGeZ8h3D4rd                          Hopes And Fears  album
# 3  2V1g8Z3d12rVQl5UIACCEI                       Dímelo En La Calle  album
# 4  2rIdWbXPjcq8K7BCccBhhC                                 Bocanada  album
#
#   release_date  total_tracks                id_artists genres  \
# 0   2013-11-05            24  [5jJWnRLQeU7fe9VaDjpIWK]
# 1         1990            25  [3qAPxVwIQRBuz5ImPUxpZT]
# 2   2004-05-10            12  [53A0W3U0s8diEn9RhXQhVz]
# 3   2002-10-05            14  [4aeIWo5CMF1uRmqgJdwkZW]
# 4   1999-06-01            15  [1QOmebWGB6FdFtW7Bo3F0W]
#
#                            label  popularity
# 0          Maldito Records, S.L.          29
# 1               Parlophone Spain          71
# 2  Universal-Island Records Ltd.          82
# 3                         Ariola          56
# 4                         Ariola          71

# %%
df_tracks.to_csv('./data/extracted_data/tracks.csv', index=False, header=True)
df_artists.to_csv('./data/extracted_data/artists.csv', index=False, header=True)
df_albums.to_csv('./data/extracted_data/albums.csv', index=False, header=True)

# %% [markdown]
# ### Tests

# %%
# Test track by name and artist
print(json.dumps(search_track('Extremoduro', 'Buscando una luna'), indent=2))
# Out:
# {
#   "album": {
#     "album_type": "album",
#     "artists": [
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#         },
#         "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#         "id": "3bgsNtcf5d5h9jbQbohfBK",
#         "name": "Extremoduro",
#         "type": "artist",
#         "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#       }
#     ],
#     "external_urls": {
#       "spotify": "https://open.spotify.com/album/3msSCqpQLoY0nl4RTSf1Is"
#     },
#     "href": "https://api.spotify.com/v1/albums/3msSCqpQLoY0nl4RTSf1Is",
#     "id": "3msSCqpQLoY0nl4RTSf1Is",
#     "images": [
#       {
#         "height": 640,
#         "url": "https://i.scdn.co/image/ab67616d0000b273489635998e8b3a9dec1ae455",
#         "width": 640
#       },
#       {
#         "height": 300,
#         "url": "https://i.scdn.co/image/ab67616d00001e02489635998e8b3a9dec1ae455",
#         "width": 300
#       },
#       {
#         "height": 64,
#         "url": "https://i.scdn.co/image/ab67616d00004851489635998e8b3a9dec1ae455",
#         "width": 64
#       }
#     ],
#     "is_playable": true,
#     "name": "Agila",
#     "release_date": "1996",
#     "release_date_precision": "year",
#     "total_tracks": 14,
#     "type": "album",
#     "uri": "spotify:album:3msSCqpQLoY0nl4RTSf1Is"
#   },
#   "artists": [
#     {
#       "external_urls": {
#         "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#       },
#       "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#       "id": "3bgsNtcf5d5h9jbQbohfBK",
#       "name": "Extremoduro",
#       "type": "artist",
#       "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#     }
#   ],
#   "disc_number": 1,
#   "duration_ms": 251733,
#   "explicit": false,
#   "external_ids": {
#     "isrc": "ES5019614000"
#   },
#   "external_urls": {
#     "spotify": "https://open.spotify.com/track/5PPwm655zF0qaG28ybUfDI"
#   },
#   "href": "https://api.spotify.com/v1/tracks/5PPwm655zF0qaG28ybUfDI",
#   "id": "5PPwm655zF0qaG28ybUfDI",
#   "is_local": false,
#   "is_playable": true,
#   "name": "Buscando una luna",
#   "popularity": 50,
#   "preview_url": "https://p.scdn.co/mp3-preview/a2014d8c6f44e92d2d3e88a2335f09bca9102aef?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#   "track_number": 1,
#   "type": "track",
#   "uri": "spotify:track:5PPwm655zF0qaG28ybUfDI"
# }

# %%
# Test song
print(json.dumps(extract_track('5PPwm655zF0qaG28ybUfDI'), indent=2))
# Out:
# {
#   "album": {
#     "album_type": "album",
#     "artists": [
#       {
#         "external_urls": {
#           "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#         },
#         "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#         "id": "3bgsNtcf5d5h9jbQbohfBK",
#         "name": "Extremoduro",
#         "type": "artist",
#         "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#       }
#     ],
#     "external_urls": {
#       "spotify": "https://open.spotify.com/album/3msSCqpQLoY0nl4RTSf1Is"
#     },
#     "href": "https://api.spotify.com/v1/albums/3msSCqpQLoY0nl4RTSf1Is",
#     "id": "3msSCqpQLoY0nl4RTSf1Is",
#     "images": [
#       {
#         "height": 640,
#         "url": "https://i.scdn.co/image/ab67616d0000b273489635998e8b3a9dec1ae455",
#         "width": 640
#       },
#       {
#         "height": 300,
#         "url": "https://i.scdn.co/image/ab67616d00001e02489635998e8b3a9dec1ae455",
#         "width": 300
#       },
#       {
#         "height": 64,
#         "url": "https://i.scdn.co/image/ab67616d00004851489635998e8b3a9dec1ae455",
#         "width": 64
#       }
#     ],
#     "is_playable": true,
#     "name": "Agila",
#     "release_date": "1996",
#     "release_date_precision": "year",
#     "total_tracks": 14,
#     "type": "album",
#     "uri": "spotify:album:3msSCqpQLoY0nl4RTSf1Is"
#   },
#   "artists": [
#     {
#       "external_urls": {
#         "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#       },
#       "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#       "id": "3bgsNtcf5d5h9jbQbohfBK",
#       "name": "Extremoduro",
#       "type": "artist",
#       "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#     }
#   ],
#   "disc_number": 1,
#   "duration_ms": 251733,
#   "explicit": false,
#   "external_ids": {
#     "isrc": "ES5019614000"
#   },
#   "external_urls": {
#     "spotify": "https://open.spotify.com/track/5PPwm655zF0qaG28ybUfDI"
#   },
#   "href": "https://api.spotify.com/v1/tracks/5PPwm655zF0qaG28ybUfDI",
#   "id": "5PPwm655zF0qaG28ybUfDI",
#   "is_local": false,
#   "is_playable": true,
#   "name": "Buscando una luna",
#   "popularity": 50,
#   "preview_url": "https://p.scdn.co/mp3-preview/a2014d8c6f44e92d2d3e88a2335f09bca9102aef?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#   "track_number": 1,
#   "type": "track",
#   "uri": "spotify:track:5PPwm655zF0qaG28ybUfDI"
# }

# %%
# Test artist
print(json.dumps(extract_artist('3bgsNtcf5d5h9jbQbohfBK'), indent=2))
# Out:
# {
#   "external_urls": {
#     "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#   },
#   "followers": {
#     "href": null,
#     "total": 1265540
#   },
#   "genres": [
#     "indie extremena",
#     "spanish rock"
#   ],
#   "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#   "id": "3bgsNtcf5d5h9jbQbohfBK",
#   "images": [
#     {
#       "height": 640,
#       "url": "https://i.scdn.co/image/ab6761610000e5eb12434039f9760438626cf90b",
#       "width": 640
#     },
#     {
#       "height": 320,
#       "url": "https://i.scdn.co/image/ab6761610000517412434039f9760438626cf90b",
#       "width": 320
#     },
#     {
#       "height": 160,
#       "url": "https://i.scdn.co/image/ab6761610000f17812434039f9760438626cf90b",
#       "width": 160
#     }
#   ],
#   "name": "Extremoduro",
#   "popularity": 63,
#   "type": "artist",
#   "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
# }

# %%
# Test albums from artist
print(json.dumps(extract_artist_albums('3bgsNtcf5d5h9jbQbohfBK'), indent=2))
# Out:
# {
#   "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK/albums?include_groups=album&offset=0&limit=20&market=ES",
#   "items": [
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/33kfD97XqCE416YXIUMdKa"
#       },
#       "href": "https://api.spotify.com/v1/albums/33kfD97XqCE416YXIUMdKa",
#       "id": "33kfD97XqCE416YXIUMdKa",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b2730c181ad7973614d699da8d5c",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e020c181ad7973614d699da8d5c",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d000048510c181ad7973614d699da8d5c",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Canciones 1989-2013",
#       "release_date": "2021-12-10",
#       "release_date_precision": "day",
#       "total_tracks": 44,
#       "type": "album",
#       "uri": "spotify:album:33kfD97XqCE416YXIUMdKa"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/75NdpQFqXPKVRJn8bqEADO"
#       },
#       "href": "https://api.spotify.com/v1/albums/75NdpQFqXPKVRJn8bqEADO",
#       "id": "75NdpQFqXPKVRJn8bqEADO",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273821ade3ac1a19d176e6167be",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02821ade3ac1a19d176e6167be",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851821ade3ac1a19d176e6167be",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Para todos los p\u00fablicos",
#       "release_date": "2013-11-08",
#       "release_date_precision": "day",
#       "total_tracks": 9,
#       "type": "album",
#       "uri": "spotify:album:75NdpQFqXPKVRJn8bqEADO"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/3JFryzZ2dByJ7Z2Ik2fVua"
#       },
#       "href": "https://api.spotify.com/v1/albums/3JFryzZ2dByJ7Z2Ik2fVua",
#       "id": "3JFryzZ2dByJ7Z2Ik2fVua",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b2734db5099df3d763840e1634a9",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e024db5099df3d763840e1634a9",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d000048514db5099df3d763840e1634a9",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Material defectuoso",
#       "release_date": "2011-05-24",
#       "release_date_precision": "day",
#       "total_tracks": 6,
#       "type": "album",
#       "uri": "spotify:album:3JFryzZ2dByJ7Z2Ik2fVua"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/1GYJUlbVr5FuNU7awwMGzu"
#       },
#       "href": "https://api.spotify.com/v1/albums/1GYJUlbVr5FuNU7awwMGzu",
#       "id": "1GYJUlbVr5FuNU7awwMGzu",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273c8d5b20f7ca690ecc816271e",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02c8d5b20f7ca690ecc816271e",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851c8d5b20f7ca690ecc816271e",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "La ley innata",
#       "release_date": "2008-08-26",
#       "release_date_precision": "day",
#       "total_tracks": 6,
#       "type": "album",
#       "uri": "spotify:album:1GYJUlbVr5FuNU7awwMGzu"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/17MLgzMkrYdEupG7D9Qm7B"
#       },
#       "href": "https://api.spotify.com/v1/albums/17MLgzMkrYdEupG7D9Qm7B",
#       "id": "17MLgzMkrYdEupG7D9Qm7B",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b27397bd8dd9685efc5aabba5607",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e0297bd8dd9685efc5aabba5607",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d0000485197bd8dd9685efc5aabba5607",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Canciones sin voz",
#       "release_date": "2004-11-15",
#       "release_date_precision": "day",
#       "total_tracks": 20,
#       "type": "album",
#       "uri": "spotify:album:17MLgzMkrYdEupG7D9Qm7B"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/3FgvMxabfL5UtlcPzASEhh"
#       },
#       "href": "https://api.spotify.com/v1/albums/3FgvMxabfL5UtlcPzASEhh",
#       "id": "3FgvMxabfL5UtlcPzASEhh",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b2737d95383aa4544f540f26c513",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e027d95383aa4544f540f26c513",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d000048517d95383aa4544f540f26c513",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Yo, Minor\u00eda Absoluta",
#       "release_date": "2002",
#       "release_date_precision": "year",
#       "total_tracks": 10,
#       "type": "album",
#       "uri": "spotify:album:3FgvMxabfL5UtlcPzASEhh"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/5QHJB2blBbAL8BjrD9hrhG"
#       },
#       "href": "https://api.spotify.com/v1/albums/5QHJB2blBbAL8BjrD9hrhG",
#       "id": "5QHJB2blBbAL8BjrD9hrhG",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b2730ebf207d528429be0eea1a6e",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e020ebf207d528429be0eea1a6e",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d000048510ebf207d528429be0eea1a6e",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Canciones Prohibidas",
#       "release_date": "1998-06-08",
#       "release_date_precision": "day",
#       "total_tracks": 10,
#       "type": "album",
#       "uri": "spotify:album:5QHJB2blBbAL8BjrD9hrhG"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/4ctycEhcvWtrS9qTggsaRP"
#       },
#       "href": "https://api.spotify.com/v1/albums/4ctycEhcvWtrS9qTggsaRP",
#       "id": "4ctycEhcvWtrS9qTggsaRP",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b27391c70aaf685b56fe67b23be9",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e0291c70aaf685b56fe67b23be9",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d0000485191c70aaf685b56fe67b23be9",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Iros Todos A Tomar Por Culo",
#       "release_date": "1997",
#       "release_date_precision": "year",
#       "total_tracks": 14,
#       "type": "album",
#       "uri": "spotify:album:4ctycEhcvWtrS9qTggsaRP"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/3msSCqpQLoY0nl4RTSf1Is"
#       },
#       "href": "https://api.spotify.com/v1/albums/3msSCqpQLoY0nl4RTSf1Is",
#       "id": "3msSCqpQLoY0nl4RTSf1Is",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273489635998e8b3a9dec1ae455",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02489635998e8b3a9dec1ae455",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851489635998e8b3a9dec1ae455",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Agila",
#       "release_date": "1996",
#       "release_date_precision": "year",
#       "total_tracks": 14,
#       "type": "album",
#       "uri": "spotify:album:3msSCqpQLoY0nl4RTSf1Is"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/03L4vb7pXkv4UCTyniPGh7"
#       },
#       "href": "https://api.spotify.com/v1/albums/03L4vb7pXkv4UCTyniPGh7",
#       "id": "03L4vb7pXkv4UCTyniPGh7",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273a50b85c857e21bf1d07529fa",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02a50b85c857e21bf1d07529fa",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851a50b85c857e21bf1d07529fa",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "D\u00f3nde Est\u00e1n Mis Amigos",
#       "release_date": "1993",
#       "release_date_precision": "year",
#       "total_tracks": 16,
#       "type": "album",
#       "uri": "spotify:album:03L4vb7pXkv4UCTyniPGh7"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/022zIyy4TicgTuuqLco8t8"
#       },
#       "href": "https://api.spotify.com/v1/albums/022zIyy4TicgTuuqLco8t8",
#       "id": "022zIyy4TicgTuuqLco8t8",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273b0fe164a8c9de1fecce0061b",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02b0fe164a8c9de1fecce0061b",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851b0fe164a8c9de1fecce0061b",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Deltoya",
#       "release_date": "1992",
#       "release_date_precision": "year",
#       "total_tracks": 20,
#       "type": "album",
#       "uri": "spotify:album:022zIyy4TicgTuuqLco8t8"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/7cMPHSCmlJVpO9EH0a6bSp"
#       },
#       "href": "https://api.spotify.com/v1/albums/7cMPHSCmlJVpO9EH0a6bSp",
#       "id": "7cMPHSCmlJVpO9EH0a6bSp",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b273a7f10e2723b166e38f98eeaa",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e02a7f10e2723b166e38f98eeaa",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d00004851a7f10e2723b166e38f98eeaa",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Somos Unos Animales",
#       "release_date": "1991",
#       "release_date_precision": "year",
#       "total_tracks": 14,
#       "type": "album",
#       "uri": "spotify:album:7cMPHSCmlJVpO9EH0a6bSp"
#     },
#     {
#       "album_group": "album",
#       "album_type": "album",
#       "artists": [
#         {
#           "external_urls": {
#             "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#           },
#           "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#           "id": "3bgsNtcf5d5h9jbQbohfBK",
#           "name": "Extremoduro",
#           "type": "artist",
#           "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#         }
#       ],
#       "external_urls": {
#         "spotify": "https://open.spotify.com/album/4f7hfg6zPldUQf9DY4ihqq"
#       },
#       "href": "https://api.spotify.com/v1/albums/4f7hfg6zPldUQf9DY4ihqq",
#       "id": "4f7hfg6zPldUQf9DY4ihqq",
#       "images": [
#         {
#           "height": 640,
#           "url": "https://i.scdn.co/image/ab67616d0000b2739c8e10eba0904524f161f872",
#           "width": 640
#         },
#         {
#           "height": 300,
#           "url": "https://i.scdn.co/image/ab67616d00001e029c8e10eba0904524f161f872",
#           "width": 300
#         },
#         {
#           "height": 64,
#           "url": "https://i.scdn.co/image/ab67616d000048519c8e10eba0904524f161f872",
#           "width": 64
#         }
#       ],
#       "is_playable": true,
#       "name": "Rock Transgresivo",
#       "release_date": "1989",
#       "release_date_precision": "year",
#       "total_tracks": 15,
#       "type": "album",
#       "uri": "spotify:album:4f7hfg6zPldUQf9DY4ihqq"
#     }
#   ],
#   "limit": 20,
#   "next": null,
#   "offset": 0,
#   "previous": null,
#   "total": 13
# }

# %%
# Test albums
print(json.dumps(extract_album('3msSCqpQLoY0nl4RTSf1Is'), indent=2))
# Out:
# {
#   "album_type": "album",
#   "artists": [
#     {
#       "external_urls": {
#         "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#       },
#       "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#       "id": "3bgsNtcf5d5h9jbQbohfBK",
#       "name": "Extremoduro",
#       "type": "artist",
#       "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#     }
#   ],
#   "copyrights": [
#     {
#       "text": "\u00a9 2010 Warner Music Spain, S.L.",
#       "type": "C"
#     },
#     {
#       "text": "\u2117 1996 DRO EAST WEST S.A.",
#       "type": "P"
#     }
#   ],
#   "external_ids": {
#     "upc": "825646758890"
#   },
#   "external_urls": {
#     "spotify": "https://open.spotify.com/album/3msSCqpQLoY0nl4RTSf1Is"
#   },
#   "genres": [],
#   "href": "https://api.spotify.com/v1/albums/3msSCqpQLoY0nl4RTSf1Is",
#   "id": "3msSCqpQLoY0nl4RTSf1Is",
#   "images": [
#     {
#       "height": 640,
#       "url": "https://i.scdn.co/image/ab67616d0000b273489635998e8b3a9dec1ae455",
#       "width": 640
#     },
#     {
#       "height": 300,
#       "url": "https://i.scdn.co/image/ab67616d00001e02489635998e8b3a9dec1ae455",
#       "width": 300
#     },
#     {
#       "height": 64,
#       "url": "https://i.scdn.co/image/ab67616d00004851489635998e8b3a9dec1ae455",
#       "width": 64
#     }
#   ],
#   "is_playable": true,
#   "label": "WM Spain",
#   "name": "Agila",
#   "popularity": 60,
#   "release_date": "1996",
#   "release_date_precision": "year",
#   "total_tracks": 14,
#   "tracks": {
#     "href": "https://api.spotify.com/v1/albums/3msSCqpQLoY0nl4RTSf1Is/tracks?offset=0&limit=50&market=ES",
#     "items": [
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 251733,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/5PPwm655zF0qaG28ybUfDI"
#         },
#         "href": "https://api.spotify.com/v1/tracks/5PPwm655zF0qaG28ybUfDI",
#         "id": "5PPwm655zF0qaG28ybUfDI",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Buscando una luna",
#         "preview_url": "https://p.scdn.co/mp3-preview/a2014d8c6f44e92d2d3e88a2335f09bca9102aef?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 1,
#         "type": "track",
#         "uri": "spotify:track:5PPwm655zF0qaG28ybUfDI"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 207826,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/18zZrM97fQtxhyaCB06ICZ"
#         },
#         "href": "https://api.spotify.com/v1/tracks/18zZrM97fQtxhyaCB06ICZ",
#         "id": "18zZrM97fQtxhyaCB06ICZ",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Prometeo",
#         "preview_url": "https://p.scdn.co/mp3-preview/d6e4ed4e678a71777a5db789607898a64bfe9ae7?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 2,
#         "type": "track",
#         "uri": "spotify:track:18zZrM97fQtxhyaCB06ICZ"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 187333,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/3qwi91kUb1BJ62DRTfcqv8"
#         },
#         "href": "https://api.spotify.com/v1/tracks/3qwi91kUb1BJ62DRTfcqv8",
#         "id": "3qwi91kUb1BJ62DRTfcqv8",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Sucede",
#         "preview_url": "https://p.scdn.co/mp3-preview/22f600ed76d0377b9440819d42bd428605d928dc?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 3,
#         "type": "track",
#         "uri": "spotify:track:3qwi91kUb1BJ62DRTfcqv8"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 281666,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/5HSpMRUC4m3L3q48to2Kmu"
#         },
#         "href": "https://api.spotify.com/v1/tracks/5HSpMRUC4m3L3q48to2Kmu",
#         "id": "5HSpMRUC4m3L3q48to2Kmu",
#         "is_local": false,
#         "is_playable": true,
#         "name": "So payaso",
#         "preview_url": "https://p.scdn.co/mp3-preview/bfe87f0d8ab597568fb4b9e3c4b0b5f9031bbd52?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 4,
#         "type": "track",
#         "uri": "spotify:track:5HSpMRUC4m3L3q48to2Kmu"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           },
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/5hkg8B49Eti6A1L5jW4hXS"
#             },
#             "href": "https://api.spotify.com/v1/artists/5hkg8B49Eti6A1L5jW4hXS",
#             "id": "5hkg8B49Eti6A1L5jW4hXS",
#             "name": "Albert Pla",
#             "type": "artist",
#             "uri": "spotify:artist:5hkg8B49Eti6A1L5jW4hXS"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 284400,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/7viUOrr9t7bX5OqNLB7xNZ"
#         },
#         "href": "https://api.spotify.com/v1/tracks/7viUOrr9t7bX5OqNLB7xNZ",
#         "id": "7viUOrr9t7bX5OqNLB7xNZ",
#         "is_local": false,
#         "is_playable": true,
#         "name": "El d\u00eda de la bestia",
#         "preview_url": "https://p.scdn.co/mp3-preview/fb13db1d73fc3cc9160c2b23695401e4e52d09fe?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 5,
#         "type": "track",
#         "uri": "spotify:track:7viUOrr9t7bX5OqNLB7xNZ"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 87373,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4Y79QqHwvABhSzQPinQNhT"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4Y79QqHwvABhSzQPinQNhT",
#         "id": "4Y79QqHwvABhSzQPinQNhT",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Tom\u00e1s",
#         "preview_url": "https://p.scdn.co/mp3-preview/d77e56366b5be19adbe0eafad8ae1992d2133b14?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 6,
#         "type": "track",
#         "uri": "spotify:track:4Y79QqHwvABhSzQPinQNhT"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 196733,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/3p0WDs3Ex2PkeBxR5kWuW7"
#         },
#         "href": "https://api.spotify.com/v1/tracks/3p0WDs3Ex2PkeBxR5kWuW7",
#         "id": "3p0WDs3Ex2PkeBxR5kWuW7",
#         "is_local": false,
#         "is_playable": true,
#         "name": "\u00a1Qu\u00e9 sonrisa tan rara!",
#         "preview_url": "https://p.scdn.co/mp3-preview/4c1f5cfcc187b14a4f45d98f49081b460452d50d?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 7,
#         "type": "track",
#         "uri": "spotify:track:3p0WDs3Ex2PkeBxR5kWuW7"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 220666,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/79BcjoCZCkSTYp5qTJ3zWb"
#         },
#         "href": "https://api.spotify.com/v1/tracks/79BcjoCZCkSTYp5qTJ3zWb",
#         "id": "79BcjoCZCkSTYp5qTJ3zWb",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Cabezabajo",
#         "preview_url": "https://p.scdn.co/mp3-preview/3933ad758a487d2bb7af9139fb0de1a828d17e65?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 8,
#         "type": "track",
#         "uri": "spotify:track:79BcjoCZCkSTYp5qTJ3zWb"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 210400,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/25ue5YVxjkihYJKpu1Lebt"
#         },
#         "href": "https://api.spotify.com/v1/tracks/25ue5YVxjkihYJKpu1Lebt",
#         "id": "25ue5YVxjkihYJKpu1Lebt",
#         "is_local": false,
#         "is_playable": true,
#         "name": "\u00c1breme el pecho y registra",
#         "preview_url": "https://p.scdn.co/mp3-preview/c527b8ff01e98db170e4ab4b6b468e0b5742024a?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 9,
#         "type": "track",
#         "uri": "spotify:track:25ue5YVxjkihYJKpu1Lebt"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 251760,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/6mrYieEu2glNBDY1DBoSxs"
#         },
#         "href": "https://api.spotify.com/v1/tracks/6mrYieEu2glNBDY1DBoSxs",
#         "id": "6mrYieEu2glNBDY1DBoSxs",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Todos me dicen",
#         "preview_url": "https://p.scdn.co/mp3-preview/673b7fbedcb3a9a855e4663e9445157dca209acd?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 10,
#         "type": "track",
#         "uri": "spotify:track:6mrYieEu2glNBDY1DBoSxs"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 152973,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/6f6SOVV9QJjWnwART9RgQJ"
#         },
#         "href": "https://api.spotify.com/v1/tracks/6f6SOVV9QJjWnwART9RgQJ",
#         "id": "6f6SOVV9QJjWnwART9RgQJ",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Correcaminos \u00a1Estate al loro!",
#         "preview_url": "https://p.scdn.co/mp3-preview/acb790cd866eda90f251e2df74449a5efb94225e?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 11,
#         "type": "track",
#         "uri": "spotify:track:6f6SOVV9QJjWnwART9RgQJ"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 136200,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4JQjChfJuCwGPYTpWfIZuw"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4JQjChfJuCwGPYTpWfIZuw",
#         "id": "4JQjChfJuCwGPYTpWfIZuw",
#         "is_local": false,
#         "is_playable": true,
#         "name": "La carrera",
#         "preview_url": "https://p.scdn.co/mp3-preview/efe6bdd3286ce5ce974ec62442a709e280c3c279?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 12,
#         "type": "track",
#         "uri": "spotify:track:4JQjChfJuCwGPYTpWfIZuw"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 132666,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/3EJid44JIEbOknxjZPp42x"
#         },
#         "href": "https://api.spotify.com/v1/tracks/3EJid44JIEbOknxjZPp42x",
#         "id": "3EJid44JIEbOknxjZPp42x",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Me estoy quitando",
#         "preview_url": "https://p.scdn.co/mp3-preview/505cb408f75580f76defdb9cb38d3c239e79426b?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 13,
#         "type": "track",
#         "uri": "spotify:track:3EJid44JIEbOknxjZPp42x"
#       },
#       {
#         "artists": [
#           {
#             "external_urls": {
#               "spotify": "https://open.spotify.com/artist/3bgsNtcf5d5h9jbQbohfBK"
#             },
#             "href": "https://api.spotify.com/v1/artists/3bgsNtcf5d5h9jbQbohfBK",
#             "id": "3bgsNtcf5d5h9jbQbohfBK",
#             "name": "Extremoduro",
#             "type": "artist",
#             "uri": "spotify:artist:3bgsNtcf5d5h9jbQbohfBK"
#           }
#         ],
#         "disc_number": 1,
#         "duration_ms": 186000,
#         "explicit": false,
#         "external_urls": {
#           "spotify": "https://open.spotify.com/track/4SyaiJNTAmXilQsq2yXUxI"
#         },
#         "href": "https://api.spotify.com/v1/tracks/4SyaiJNTAmXilQsq2yXUxI",
#         "id": "4SyaiJNTAmXilQsq2yXUxI",
#         "is_local": false,
#         "is_playable": true,
#         "name": "Sucede - Versi\u00f3n 2004",
#         "preview_url": "https://p.scdn.co/mp3-preview/94055ac1c9b4642d9a650a5177e73794de450aa5?cid=755baf36b7e94f81ba6f0d30c9783a4e",
#         "track_number": 14,
#         "type": "track",
#         "uri": "spotify:track:4SyaiJNTAmXilQsq2yXUxI"
#       }
#     ],
#     "limit": 50,
#     "next": null,
#     "offset": 0,
#     "previous": null,
#     "total": 14
#   },
#   "type": "album",
#   "uri": "spotify:album:3msSCqpQLoY0nl4RTSf1Is"
# }
